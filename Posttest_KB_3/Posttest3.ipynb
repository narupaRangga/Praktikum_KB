# %% [markdown]
# # POSTTEST 3 KECERDASAN BUATAN
# ### Nama: Narupa Rangga Goroguta
# ###  NIM: 2209106004
# ### Kelas: A1 2022

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('income.csv')
df_income = pd.read_csv('income.csv')  
df_income.head()
# Out:
#    age         workclass  fnlwgt     education  education.num  \
# 0   40  Self-emp-not-inc  223881   Prof-school             15
# 1   30           Private  149118       HS-grad              9
# 2   46           Private  109209  Some-college             10
# 3   32           Private  229566     Assoc-voc             11
# 4   54                 ?  148657     Preschool              1
#
#        marital.status      occupation   relationship   race     sex  \
# 0  Married-civ-spouse  Prof-specialty        Husband  White    Male
# 1            Divorced    Craft-repair  Not-in-family  White  Female
# 2  Married-civ-spouse    Adm-clerical        Husband  White    Male
# 3  Married-civ-spouse   Other-service        Husband  White    Male
# 4  Married-civ-spouse               ?           Wife  White  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0         99999             0              70  United-States   >50K
# ...

# %%
df.set_index('age', inplace=True)
df.head()
# Out:
#             workclass  fnlwgt     education  education.num  \
# age
# 40   Self-emp-not-inc  223881   Prof-school             15
# 30            Private  149118       HS-grad              9
# 46            Private  109209  Some-college             10
# 32            Private  229566     Assoc-voc             11
# 54                  ?  148657     Preschool              1
#
#          marital.status      occupation   relationship   race     sex  \
# age
# 40   Married-civ-spouse  Prof-specialty        Husband  White    Male
# 30             Divorced    Craft-repair  Not-in-family  White  Female
# 46   Married-civ-spouse    Adm-clerical        Husband  White    Male
# 32   Married-civ-spouse   Other-service        Husband  White    Male
# 54   Married-civ-spouse               ?           Wife  White  Female
#
#      capital.gain  capital.loss  hours.per.week native.country income
# age
# 40          99999             0              70  United-States   >50K
# ...

# %%
df.loc[30,'workclass']
# Out:
# age
# 30      Private
# 30    State-gov
# 30      Private
# 30      Private
# 30      Private
#         ...
# 30      Private
# 30    State-gov
# 30      Private
# 30      Private
# 30      Private
# Name: workclass, Length: 671, dtype: object

# %%
dataFrame.tail()
# Out:
#        age    workclass  fnlwgt     education  education.num  \
# 24995   40      Private  130834  Some-college             10
# 24996   31    Local-gov   33124     Bachelors             13
# 24997   38  Federal-gov  190895     Bachelors             13
# 24998   23      Private  420973     Bachelors             13
# 24999   60      Private   88055          10th              6
#
#            marital.status        occupation   relationship   race     sex  \
# 24995       Never-married      Adm-clerical  Not-in-family  White  Female
# 24996       Never-married    Prof-specialty  Not-in-family  White  Female
# 24997  Married-civ-spouse    Prof-specialty        Husband  White    Male
# 24998       Never-married    Prof-specialty  Not-in-family  White  Female
# 24999  Married-civ-spouse  Transport-moving        Husband  White    Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 24995             0             0              40  United-States  <=50K
# ...

# %%
data = df_income.groupby('workclass').sum()
data
# Out:
#                      age      fnlwgt  \
# workclass
# ?                  58130   268564225
# Federal-gov        31545   137825866
# Local-gov          64774   291786136
# Never-worked         106      962502
# Private           644755  3363080667
# Self-emp-inc       38975   150696960
# Self-emp-not-inc   87014   342106431
# State-gov          39352   184448543
# Without-pay          578     2057043
#
#                                                           education  \
# workclass
# ?                 PreschoolSome-collegeSome-college5th-6thMaster...
# Federal-gov       HS-gradHS-gradMastersHS-gradSome-collegeBachel...
# Local-gov         HS-gradHS-gradHS-gradHS-gradHS-gradBachelorsAs...
# Never-worked                     Some-college10thHS-grad10th7th-8th
# Private           HS-gradSome-collegeAssoc-vocSome-college7th-8t...
# Self-emp-inc      HS-gradBachelorsProf-schoolSome-collegeSome-co...
# Self-emp-not-inc  Prof-schoolSome-collegeProf-school10thBachelor...
# ...

# %%
data_df = df['workclass'].value_counts()
data_df
# Out:
# workclass
# Private             17471
# Self-emp-not-inc     1935
# Local-gov            1553
# ?                    1429
# State-gov            1004
# Self-emp-inc          851
# Federal-gov           740
# Without-pay            12
# Never-worked            5
# Name: count, dtype: int64

# %%
# pandas
data_df.plot.bar()
plt.title('pendapatan')
plt.xlabel('jenis')
plt.ylabel('panjang')
plt.show()

# %% [markdown]
# # Diagram Batang
# ### dari diagram batang  diatas bisa disimpulakan bahwa, melihat dari kelas pekerjaan pendapatan lebih tinggi di dapat oleh masyarakat yang punya usaha sendiri atau private.

# %%
data = df.income.value_counts()

plt.pie(data, labels=data.index, autopct="%1.1f%%")

plt.title('jumlah Data')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Pie Chart
# ### dari presentase di atas bisa disimpulkan bahwa pendapatan masyarakat amerika 75.8% lebih banyak dari 50k dan 24.2% kurang dari 50k.

# %%
plt.hist(df['workclass'])
plt.title('pendapatan')
plt.xlabel('jenis')
plt.ylabel('panjang')
plt.show()

# %%
# seaborn
df_corr = df.loc[:, 'capital.gain':'hours.per.week'].corr()
df_corr
# Out:
#                 capital.gain  capital.loss  hours.per.week
# capital.gain        1.000000     -0.032130        0.075063
# capital.loss       -0.032130      1.000000        0.054526
# hours.per.week      0.075063      0.054526        1.000000

# %% [markdown]
# # Histogram
# ### nilai yang sering muncul pada data pendapatan masarakat amerika ialah nilai private sebesar 17500

# %%
sns.heatmap(df_corr , annot=True, cmap='cividis')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # heatmap
# ### korelasi antara capital gain dan hours per week lebih tinggi dibandingkan yang lain
