# %% [markdown]
# # POSTTEST 2
# # American Citizens Annual Income
#
# ### Nama: Narupa Rangga Goroguta
# ### NIM : 2209016004
# ### Kelas : A1 22 Kecerdasan Buatan

# %%
import pandas as pd
dataFrame = pd.read_csv('income.csv')

# %% [markdown]
# ### Menampilkan nilai rata-rata, Standar deviasi, nilai minumum, nilai maksimum, Q1,Q2,Q3 dari attribute

# %%
dataFrame.describe()
# Out:
#                age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  25000.00000  2.500000e+04   25000.000000  25000.000000  25000.000000
# mean      38.60916  1.896611e+05      10.076320   1083.144040     87.489800
# std       13.68660  1.054713e+05       2.576967   7321.971568    402.830246
# min       17.00000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.00000  1.179830e+05       9.000000      0.000000      0.000000
# 50%       37.00000  1.782110e+05      10.000000      0.000000      0.000000
# 75%       48.00000  2.370682e+05      12.000000      0.000000      0.000000
# max       90.00000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    25000.000000
# mean        40.442800
# std         12.309706
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# ### Menampilkan 10 record pertama

# %%
dataFrame.head(10)
# Out:
#    age         workclass  fnlwgt     education  education.num  \
# 0   40  Self-emp-not-inc  223881   Prof-school             15
# 1   30           Private  149118       HS-grad              9
# 2   46           Private  109209  Some-college             10
# 3   32           Private  229566     Assoc-voc             11
# 4   54                 ?  148657     Preschool              1
# 5   63           Private  111963  Some-college             10
# 6   25           Private  207875       7th-8th              4
# 7   71         Local-gov  229110       HS-grad              9
# 8   37           Private   66686       HS-grad              9
# 9   44           Private  227399     Assoc-voc             11
#
#        marital.status         occupation    relationship   race     sex  \
# 0  Married-civ-spouse     Prof-specialty         Husband  White    Male
# 1            Divorced       Craft-repair   Not-in-family  White  Female
# ...

# %% [markdown]
# ### Menampilakan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka

# %%
jumlah_record = dataFrame.shape[0]
jumlah_attribute = len(dataFrame.columns)
nama_attribute = dataFrame.columns.tolist()
jumlah_attribute_angka = len(dataFrame.select_dtypes('int').columns)

info = {
    "jumlah record" : jumlah_record,
    "jumlah attribute" : jumlah_attribute,
    "Nama attribute" : nama_attribute,
    "jumlah attribute bertipe angka" : jumlah_attribute_angka
}

for key, value in info.items():
    print(key, ":", value)
# Out:
# jumlah record : 25000
# jumlah attribute : 15
# Nama attribute : ['age', 'workclass', 'fnlwgt', 'education', 'education.num', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'capital.gain', 'capital.loss', 'hours.per.week', 'native.country', 'income']
# jumlah attribute bertipe angka : 6

# %% [markdown]
# ### Menampilkan nilai pada baris dimulai dari 3 digit NIM akhir hingga data terakhir dan ke kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode silce

# %%
dataFrame.iloc[4:, 4:]
# Out:
#        education.num      marital.status         occupation    relationship  \
# 4                  1  Married-civ-spouse                  ?            Wife
# 5                 10  Married-civ-spouse     Prof-specialty         Husband
# 6                  4  Married-civ-spouse  Handlers-cleaners         Husband
# 7                  9             Widowed    Exec-managerial  Other-relative
# 8                  9  Married-civ-spouse  Handlers-cleaners         Husband
# ...              ...                 ...                ...             ...
# 24995             10       Never-married       Adm-clerical   Not-in-family
# 24996             13       Never-married     Prof-specialty   Not-in-family
# 24997             13  Married-civ-spouse     Prof-specialty         Husband
# 24998             13       Never-married     Prof-specialty   Not-in-family
# 24999              6  Married-civ-spouse   Transport-moving         Husband
#
# ...

# %% [markdown]
# ### Menampilkan jumlah nilai dari semua attribute yang bernilai object (contoh : jenis kelamin,Agama)

# %%
len(dataFrame.select_dtypes('object'))
# Out:
# 25000
